# %% [markdown]
# <a href="https://colab.research.google.com/github/afnanAlgognadi/Introduction-to-Machine-Learning/blob/main/Solution_OSAP_LogisticRegression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plotClass(X,y,p):
    plt.figure()
    for i in range(y.shape[1]):
        if y[0,i]==0:
            plt.plot(X[0,i],X[1,i],'r'+p)
        else:
            plt.plot(X[0,i],X[1,i],'b'+p)

# %%
num_data=100 # data points per class

x1=np.random.randn(2,num_data)+2
x0=np.random.randn(2,num_data)

y1=np.ones((1,num_data))
y0=np.zeros((1,num_data))

X=np.concatenate((x1,x0),axis=1)
y=np.concatenate((y1,y0), axis=1)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 200)
# (1, 200)

# %%
def get_z(W, X, b):
  #w0+w1*x1+w2*x2
  return W@X+b


def get_sigmoid(z):
  return 1/(1+np.exp(-z))


def get_loss(y,yhat):
  return np.sum(-y*np.log(yhat) -(1-y)*np.log(1-yhat), axis=1)/ y.shape[1]


W = np.random.randn(1,X.shape[0])
b = 0
ls =[]
lr=0.0001
for i in range(1000):
  z = get_z(W,X,b)
  yhat = get_sigmoid(z)

  loss = get_loss(y,yhat)
  ls.append(loss)
  # dZ=dJ/dy * dy/ dZ
  dZ = yhat - y

  dW = dZ @ X.T
  db = np.sum(dZ)


  W -=lr*dW
  b -=lr*db


plt.plot(ls)

# %%
plotClass(X,y,'o')
print(X.shape)
print(y.shape)

x1= np.linspace(-4,4,100)

x2 = (-b -W[0,0]*x1)/W[0,1]
plt.plot(x1,x2)
plt.show()
# Out:
# (2, 200)
# (1, 200)

# %%
plotClass(X, yhat>0.5,'o')
plotClass(X,y,'x')

# %%
np.sum(y==(yhat>0.5))/y.shape[1]
# Out:
# 0.94

# %%
x1= np.linspace(-4,4,100)
x2= np.linspace(-4,4,100)

[X1, X2] = np.meshgrid(x1,x2)

data = [X1.flatten(), X2.flatten()]
data = np.array(data)

z= get_z(W, data, b)
yhat = z>0

plotClass(data, yhat, '.')
